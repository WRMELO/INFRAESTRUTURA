# %%
# ================================
# 🧪 Diagnóstico individual da imagem no staging-unique
# ================================

import os
import io
import numpy as np
from PIL import Image
from minio import Minio

# --- Conexão com MinIO ---
minio_client = Minio(
    endpoint="minio:9000",
    access_key="admin",
    secret_key="senhasegura",
    secure=False
)

# --- Parâmetros ---
bucket = "staging-unique"
tipo_curadoria = "RL"  # ou "DL"

# Critérios (ajustados para FIAP)
criterios = {
    "DL": {"min_res": (100, 100), "max_size": 2_000_000, "force_rgb": True, "allowed_exts": [".png"]},
    "RL": {"min_res": (100, 100), "max_size": 1_000_000, "force_rgb": False, "allowed_exts": [".png", ".jpg", ".jpeg"]}
}

# --- Seleciona uma imagem manualmente (exemplo direto) ---
obj = next(minio_client.list_objects(bucket, recursive=True))
response = minio_client.get_object(bucket, obj.object_name)
data = response.read()

# --- Processamento ---
img = Image.open(io.BytesIO(data))
w, h = img.size
aspect_ratio = round(w / h, 2)
mode = img.mode
file_ext = os.path.splitext(obj.object_name)[1].lower()
std_pixels = np.array(img).std()
tamanho_bytes = len(data)

# --- Critérios aplicados ---
crit = criterios[tipo_curadoria]
comentario = None

if file_ext not in crit["allowed_exts"]:
    comentario = "Formato não permitido"
elif w < crit["min_res"][0] or h < crit["min_res"][1]:
    comentario = "Resolução insuficiente"
elif tamanho_bytes > crit["max_size"]:
    comentario = "Tamanho do arquivo excede o limite"
elif crit["force_rgb"] and mode != "RGB":
    comentario = "Imagem não está em RGB"
elif not (0.5 <= w / h <= 4.0):
    comentario = "Aspect ratio fora do intervalo"
elif std_pixels < 5:
    comentario = "Baixa variância de pixels"

# --- Resultado ---
print("📂 Arquivo:", obj.object_name)
print(f"📐 Resolução: {w}x{h}")
print(f"📦 Tamanho: {tamanho_bytes:,} bytes")
print(f"🎨 Modo de cor: {mode}")
print(f"📏 Aspect ratio: {aspect_ratio}")
print(f"📊 Desvio padrão dos pixels: {round(std_pixels, 2)}")
print("🧪 Critérios:", crit)

if comentario:
    print(f"\n❌ Rejeitado: {comentario}")
else:
    print("\n✅ Aprovado para curadoria pesada.")
# Out:
# 📂 Arquivo: FDL/BBAS3.SA/imagens/teste/comprar/2019-04-29_1.png
# 📐 Resolução: 100x333
# 📦 Tamanho: 2,420 bytes
# 🎨 Modo de cor: L
# 📏 Aspect ratio: 0.3
# 📊 Desvio padrão dos pixels: 120.04
# 🧪 Critérios: {'min_res': (100, 100), 'max_size': 1000000, 'force_rgb': False, 'allowed_exts': ['.png', '.jpg', '.jpeg']}
#
# ❌ Rejeitado: Aspect ratio fora do intervalo

# %%
# ✅ Diagnóstico técnico da tabela curation_audit (teste isolado)

from sqlalchemy import create_engine, MetaData, Table
from datetime import datetime
import json

# --- Conexão com PostgreSQL ---
engine = create_engine("postgresql+psycopg2://postgres:senhasegura@database-services:5432/postgres")

# --- Refletir metadados ---
metadata = MetaData()
metadata.reflect(bind=engine)

if "curation_audit" not in metadata.tables:
    raise Exception("❌ Tabela 'curation_audit' não encontrada no banco de dados.")

table = metadata.tables["curation_audit"]
print("✅ Colunas encontradas na tabela:")
print(list(table.columns.keys()))

# --- Simular um insert com dados completos (adaptar se necessário) ---
test_data = {
    "full_path": "curated-unique/FDL/teste.png",
    "filename": "teste.png",
    "file_ext": ".png",
    "prefix": "FDL",
    "tipo": "DL",
    "finalidade": "pesada",
    "bucket_origem": "staging-unique",
    "bucket_destino": "curated-unique",
    "status": "processed",
    "comentario": "inserção de teste",
    "curation_type": "DL",
    "curation_status": "processed",
    "timestamp": datetime.now(),
    "curation_details": json.dumps({
        "res_w": 100,
        "res_h": 100,
        "aspect_ratio": 1.0,
        "file_size": 2000,
        "std": 15.5,
        "modo_final": "L"
    })
}

# --- Tentativa de inserção e captura do erro ---
try:
    with engine.begin() as conn:
        conn.execute(table.insert().values(test_data))
    print("✅ Inserção de teste bem-sucedida.")
except Exception as e:
    print("❌ Erro ao inserir na tabela curation_audit:")
    print(e)
# Out:
# ✅ Colunas encontradas na tabela:
# ['id', 'prefix', 'full_path', 'filename', 'file_ext', 'curation_type', 'curation_details', 'timestamp', 'source_path', 'bucket_origin', 'bucket_curated', 'curation_status']
# ❌ Erro ao inserir na tabela curation_audit:
# Unconsumed column names: comentario, tipo, status, bucket_origem, bucket_destino, finalidade

# %%
# =============================
# 🧹 Limpeza total do bucket curated-unique
# =============================

from minio import Minio

minio_client = Minio("minio:9000", access_key="admin", secret_key="senhasegura", secure=False)
bucket = "curated-unique"

if minio_client.bucket_exists(bucket):
    print(f"🧹 Apagando arquivos em '{bucket}'...")
    objetos = minio_client.list_objects(bucket, recursive=True)
    for obj in objetos:
        minio_client.remove_object(bucket, obj.object_name)
    print("✅ Bucket limpo.")
else:
    print("❌ Bucket não encontrado.")
# Out:
# 🧹 Apagando arquivos em 'curated-unique'...
# ✅ Bucket limpo.

# %%
# =============================
# 🧹 Limpeza total da tabela curation_audit
# =============================

from sqlalchemy import create_engine, text

# Conexão
engine = create_engine("postgresql+psycopg2://postgres:senhasegura@database-services:5432/postgres")

with engine.begin() as conn:
    conn.execute(text("DELETE FROM curation_audit;"))
    print("✅ Tabela 'curation_audit' zerada com sucesso.")
# Out:
# ✅ Tabela 'curation_audit' zerada com sucesso.

# %%
# =============================
# 🔍 Inspeção do schema da tabela curation_audit
# =============================

from sqlalchemy import MetaData

# Conectar e refletir estrutura
metadata = MetaData()
metadata.reflect(bind=engine)
curation_table = metadata.tables["curation_audit"]

# Exibir colunas e tipos
print("📋 Colunas da tabela 'curation_audit':\n")
for col in curation_table.columns:
    nullable = "NULL OK" if col.nullable else "NOT NULL"
    print(f"• {col.name:20} | {col.type} | {nullable}")
# Out:
# 📋 Colunas da tabela 'curation_audit':
#
# • id                   | INTEGER | NOT NULL
# • prefix               | TEXT | NOT NULL
# • full_path            | TEXT | NOT NULL
# • filename             | TEXT | NOT NULL
# • file_ext             | VARCHAR(10) | NOT NULL
# • curation_type        | TEXT | NOT NULL
# • curation_details     | TEXT | NULL OK
# • timestamp            | TIMESTAMP | NOT NULL
# • source_path          | TEXT | NOT NULL
# • bucket_origin        | TEXT | NOT NULL
# • bucket_curated       | TEXT | NOT NULL
# • curation_status      | TEXT | NULL OK

# %%
# =============================
# 🔎 Reforço: logging de valores antes do INSERT
# =============================

for obj in tqdm(objetos_validos, desc="🔁 Debug dos objetos"):
    try:
        object_name = obj.object_name

        # Segurança: validar nome
        if not object_name or not isinstance(object_name, str) or object_name.strip() == "":
            print(f"⚠️ Nome inválido detectado: '{object_name}' — pulando.")
            continue

        raw_data = minio_client.get_object(bucket_origem, object_name).read()
        Image.open(io.BytesIO(raw_data))  # valida imagem

        # Upload
        minio_client.put_object(
            bucket_name=bucket_destino,
            object_name=object_name,
            data=io.BytesIO(raw_data),
            length=len(raw_data),
            content_type="image/png"
        )

        full_path = f"{bucket_destino}/{object_name}"
        source_path = f"{bucket_origem}/{object_name}"
        filename = os.path.basename(object_name)

        # Validação extra
        if not full_path or "None" in full_path or full_path.strip() == "":
            print(f"❌ full_path inválido: '{full_path}' ← object_name: '{object_name}'")
            continue

        audit = {
            "prefix": object_name.split("/")[0],
            "full_path": full_path,
            "filename": filename,
            "file_ext": os.path.splitext(object_name)[1].lower(),
            "curation_type": "manual_check",
            "curation_details": json.dumps({"bytes": len(raw_data)}),
            "timestamp": datetime.now(),
            "source_path": source_path,
            "bucket_origin": bucket_origem,
            "bucket_curated": bucket_destino,
            "curation_status": "verificacao"
        }

        with engine.begin() as conn:
            conn.execute(curation_table.insert().values(audit))
            copiados += 1

    except Exception as e:
        print(f"❌ Erro ao copiar {object_name}: {e}")
        erros += 1
# Out:
# 🔁 Debug dos objetos:   0%|          | 0/100 [00:00<?, ?it/s]
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-04-29_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110280, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-04-29_1.p..., 2019-04-29_1.png, .png, manual_check, {"bytes": 2420}, 2025-06-01 11:53:36.832445+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-04-29_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-04-29_1.png', 'filename': '2019-04-29_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2420}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 832445), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-04-29_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-04-30_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110281, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-04-30_1.p..., 2019-04-30_1.png, .png, manual_check, {"bytes": 2452}, 2025-06-01 11:53:36.840495+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-04-30_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-04-30_1.png', 'filename': '2019-04-30_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2452}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 840495), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-04-30_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-05-02_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110282, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-02_1.p..., 2019-05-02_1.png, .png, manual_check, {"bytes": 2295}, 2025-06-01 11:53:36.849971+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-02_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-02_1.png', 'filename': '2019-05-02_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2295}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 849971), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-02_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-05-03_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110283, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-03_1.p..., 2019-05-03_1.png, .png, manual_check, {"bytes": 2322}, 2025-06-01 11:53:36.861411+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-03_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-03_1.png', 'filename': '2019-05-03_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2322}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 861411), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-03_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-05-06_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110284, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-06_1.p..., 2019-05-06_1.png, .png, manual_check, {"bytes": 2257}, 2025-06-01 11:53:36.870971+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-06_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-06_1.png', 'filename': '2019-05-06_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2257}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 870971), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-06_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-05-07_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110285, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-07_1.p..., 2019-05-07_1.png, .png, manual_check, {"bytes": 2303}, 2025-06-01 11:53:36.880025+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-07_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-07_1.png', 'filename': '2019-05-07_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2303}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 880025), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-07_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-05-08_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110286, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-08_1.p..., 2019-05-08_1.png, .png, manual_check, {"bytes": 2298}, 2025-06-01 11:53:36.889139+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-08_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-08_1.png', 'filename': '2019-05-08_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2298}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 889139), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-08_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-05-09_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110287, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-09_1.p..., 2019-05-09_1.png, .png, manual_check, {"bytes": 2231}, 2025-06-01 11:53:36.897753+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-09_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-09_1.png', 'filename': '2019-05-09_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2231}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 897753), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-09_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-05-10_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110288, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-10_1.p..., 2019-05-10_1.png, .png, manual_check, {"bytes": 2143}, 2025-06-01 11:53:36.904781+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-10_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-10_1.png', 'filename': '2019-05-10_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2143}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 904781), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-10_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-05-23_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110289, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-23_1.p..., 2019-05-23_1.png, .png, manual_check, {"bytes": 2257}, 2025-06-01 11:53:36.914584+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-23_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-23_1.png', 'filename': '2019-05-23_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2257}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 914584), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-23_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-05-24_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110290, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-24_1.p..., 2019-05-24_1.png, .png, manual_check, {"bytes": 2143}, 2025-06-01 11:53:36.924339+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-24_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-24_1.png', 'filename': '2019-05-24_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2143}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 924339), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-24_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-05-27_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110291, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-27_1.p..., 2019-05-27_1.png, .png, manual_check, {"bytes": 2122}, 2025-06-01 11:53:36.933854+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-27_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-27_1.png', 'filename': '2019-05-27_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2122}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 933854), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-27_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-05-28_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110292, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-28_1.p..., 2019-05-28_1.png, .png, manual_check, {"bytes": 2211}, 2025-06-01 11:53:36.940323+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-28_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-28_1.png', 'filename': '2019-05-28_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2211}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 940323), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-28_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-05-29_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110293, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-29_1.p..., 2019-05-29_1.png, .png, manual_check, {"bytes": 2201}, 2025-06-01 11:53:36.949133+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-29_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-29_1.png', 'filename': '2019-05-29_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2201}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 949133), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-29_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-05-30_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110294, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-30_1.p..., 2019-05-30_1.png, .png, manual_check, {"bytes": 2137}, 2025-06-01 11:53:36.958936+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-30_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-30_1.png', 'filename': '2019-05-30_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2137}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 958936), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-30_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-05-31_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110295, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-31_1.p..., 2019-05-31_1.png, .png, manual_check, {"bytes": 2160}, 2025-06-01 11:53:36.96868+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-31_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-31_1.png', 'filename': '2019-05-31_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2160}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 968680), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-05-31_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-03_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110296, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-03_1.p..., 2019-06-03_1.png, .png, manual_check, {"bytes": 2093}, 2025-06-01 11:53:36.977933+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-03_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-03_1.png', 'filename': '2019-06-03_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2093}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 977933), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-03_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-04_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110297, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-04_1.p..., 2019-06-04_1.png, .png, manual_check, {"bytes": 1869}, 2025-06-01 11:53:36.987854+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-04_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-04_1.png', 'filename': '2019-06-04_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 1869}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 987854), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-04_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-05_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110298, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-05_1.p..., 2019-06-05_1.png, .png, manual_check, {"bytes": 1816}, 2025-06-01 11:53:36.997117+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-05_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-05_1.png', 'filename': '2019-06-05_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 1816}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 36, 997117), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-05_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-06_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110299, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-06_1.p..., 2019-06-06_1.png, .png, manual_check, {"bytes": 1857}, 2025-06-01 11:53:37.008698+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-06_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-06_1.png', 'filename': '2019-06-06_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 1857}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 8698), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-06_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-07_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110300, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-07_1.p..., 2019-06-07_1.png, .png, manual_check, {"bytes": 1808}, 2025-06-01 11:53:37.019147+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-07_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-07_1.png', 'filename': '2019-06-07_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 1808}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 19147), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-07_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-10_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110301, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-10_1.p..., 2019-06-10_1.png, .png, manual_check, {"bytes": 1936}, 2025-06-01 11:53:37.028588+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-10_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-10_1.png', 'filename': '2019-06-10_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 1936}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 28588), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-10_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-11_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110302, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-11_1.p..., 2019-06-11_1.png, .png, manual_check, {"bytes": 1906}, 2025-06-01 11:53:37.04024+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-11_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-11_1.png', 'filename': '2019-06-11_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 1906}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 40240), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-11_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-12_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110303, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-12_1.p..., 2019-06-12_1.png, .png, manual_check, {"bytes": 2048}, 2025-06-01 11:53:37.050227+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-12_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-12_1.png', 'filename': '2019-06-12_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2048}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 50227), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-12_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-13_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110304, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-13_1.p..., 2019-06-13_1.png, .png, manual_check, {"bytes": 2322}, 2025-06-01 11:53:37.060528+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-13_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-13_1.png', 'filename': '2019-06-13_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2322}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 60528), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-13_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-21_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110305, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-21_1.p..., 2019-06-21_1.png, .png, manual_check, {"bytes": 2350}, 2025-06-01 11:53:37.07114+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-21_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-21_1.png', 'filename': '2019-06-21_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2350}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 71140), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-21_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-24_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110306, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-24_1.p..., 2019-06-24_1.png, .png, manual_check, {"bytes": 2397}, 2025-06-01 11:53:37.080794+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-24_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-24_1.png', 'filename': '2019-06-24_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2397}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 80794), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-24_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-25_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110307, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-25_1.p..., 2019-06-25_1.png, .png, manual_check, {"bytes": 2299}, 2025-06-01 11:53:37.091769+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-25_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-25_1.png', 'filename': '2019-06-25_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2299}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 91769), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-25_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-26_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110308, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-26_1.p..., 2019-06-26_1.png, .png, manual_check, {"bytes": 2309}, 2025-06-01 11:53:37.102346+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-26_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-26_1.png', 'filename': '2019-06-26_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2309}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 102346), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-26_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-27_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110309, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-27_1.p..., 2019-06-27_1.png, .png, manual_check, {"bytes": 2261}, 2025-06-01 11:53:37.111322+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-27_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-27_1.png', 'filename': '2019-06-27_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2261}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 111322), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-27_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-06-28_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110310, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-28_1.p..., 2019-06-28_1.png, .png, manual_check, {"bytes": 2276}, 2025-06-01 11:53:37.12057+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-28_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-28_1.png', 'filename': '2019-06-28_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2276}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 120570), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-06-28_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-07-01_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110311, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-07-01_1.p..., 2019-07-01_1.png, .png, manual_check, {"bytes": 2198}, 2025-06-01 11:53:37.130694+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-07-01_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-07-01_1.png', 'filename': '2019-07-01_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2198}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 130694), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-07-01_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2019-07-02_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110312, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-07-02_1.p..., 2019-07-02_1.png, .png, manual_check, {"bytes": 2118}, 2025-06-01 11:53:37.141757+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2019-07-02_1.p..., staging-unique, curated-unique, verificacao).
#
# ...
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-02_1.png', 'filename': '2020-06-02_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2065}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 619297), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-02_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2020-06-03_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110370, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-03_1.p..., 2020-06-03_1.png, .png, manual_check, {"bytes": 2226}, 2025-06-01 11:53:37.628147+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-03_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-03_1.png', 'filename': '2020-06-03_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2226}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 628147), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-03_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2020-06-04_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110371, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-04_1.p..., 2020-06-04_1.png, .png, manual_check, {"bytes": 1923}, 2025-06-01 11:53:37.636966+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-04_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-04_1.png', 'filename': '2020-06-04_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 1923}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 636966), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-04_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2020-06-05_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110372, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-05_1.p..., 2020-06-05_1.png, .png, manual_check, {"bytes": 2191}, 2025-06-01 11:53:37.646231+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-05_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-05_1.png', 'filename': '2020-06-05_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2191}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 646231), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-05_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2020-06-08_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110373, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-08_1.p..., 2020-06-08_1.png, .png, manual_check, {"bytes": 1907}, 2025-06-01 11:53:37.655718+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-08_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-08_1.png', 'filename': '2020-06-08_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 1907}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 655718), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-08_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2020-06-09_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110374, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-09_1.p..., 2020-06-09_1.png, .png, manual_check, {"bytes": 2045}, 2025-06-01 11:53:37.664619+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-09_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-09_1.png', 'filename': '2020-06-09_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2045}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 664619), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-09_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2020-06-10_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110375, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-10_1.p..., 2020-06-10_1.png, .png, manual_check, {"bytes": 1949}, 2025-06-01 11:53:37.675399+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-10_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-10_1.png', 'filename': '2020-06-10_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 1949}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 675399), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-10_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2020-06-12_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110376, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-12_1.p..., 2020-06-12_1.png, .png, manual_check, {"bytes": 2072}, 2025-06-01 11:53:37.687344+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-12_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-12_1.png', 'filename': '2020-06-12_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2072}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 687344), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-12_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2020-06-15_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110377, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-15_1.p..., 2020-06-15_1.png, .png, manual_check, {"bytes": 2142}, 2025-06-01 11:53:37.698114+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-15_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-15_1.png', 'filename': '2020-06-15_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 2142}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 698114), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-15_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2020-06-16_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110378, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-16_1.p..., 2020-06-16_1.png, .png, manual_check, {"bytes": 1937}, 2025-06-01 11:53:37.707758+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-16_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-16_1.png', 'filename': '2020-06-16_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 1937}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 707758), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-16_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ Erro ao copiar FDL/BBAS3.SA/imagens/teste/comprar/2020-06-17_1.png: (psycopg2.errors.CheckViolation) new row for relation "curation_audit" violates check constraint "curation_audit_curation_status_check"
# DETAIL:  Failing row contains (110379, FDL, curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-17_1.p..., 2020-06-17_1.png, .png, manual_check, {"bytes": 1872}, 2025-06-01 11:53:37.719873+00, staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-17_1.p..., staging-unique, curated-unique, verificacao).
#
# [SQL: INSERT INTO curation_audit (prefix, full_path, filename, file_ext, curation_type, curation_details, timestamp, source_path, bucket_origin, bucket_curated, curation_status) VALUES (%(prefix)s, %(full_path)s, %(filename)s, %(file_ext)s, %(curation_type)s, %(curation_details)s, %(timestamp)s, %(source_path)s, %(bucket_origin)s, %(bucket_curated)s, %(curation_status)s) RETURNING curation_audit.id]
# [parameters: {'prefix': 'FDL', 'full_path': 'curated-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-17_1.png', 'filename': '2020-06-17_1.png', 'file_ext': '.png', 'curation_type': 'manual_check', 'curation_details': '{"bytes": 1872}', 'timestamp': datetime.datetime(2025, 6, 1, 11, 53, 37, 719873), 'source_path': 'staging-unique/FDL/BBAS3.SA/imagens/teste/comprar/2020-06-17_1.png', 'bucket_origin': 'staging-unique', 'bucket_curated': 'curated-unique', 'curation_status': 'verificacao'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# =============================
# 🔍 Listar restrições CHECK da tabela curation_audit
# =============================

from sqlalchemy import inspect

insp = inspect(engine)
checks = insp.get_check_constraints("curation_audit")

print("🔎 Restrições CHECK na tabela 'curation_audit':")
for check in checks:
    print(f"• {check['name']}: {check['sqltext']}")
# Out:
# 🔎 Restrições CHECK na tabela 'curation_audit':
# • curation_audit_curation_status_check: curation_status = ANY (ARRAY['processed'::text, 'not_processed'::text])

# %%
# =============================
# ✅ Versão final com valores permitidos pelo CHECK constraint
# =============================

import io
import os
import json
from datetime import datetime
from PIL import Image
from minio import Minio
from sqlalchemy import create_engine, MetaData, Table
from tqdm.notebook import tqdm

# Conexões
minio_client = Minio("minio:9000", access_key="admin", secret_key="senhasegura", secure=False)
engine = create_engine("postgresql+psycopg2://postgres:senhasegura@database-services:5432/postgres")

# Buckets
bucket_origem = "staging-unique"
bucket_destino = "curated-unique"
if not minio_client.bucket_exists(bucket_destino):
    minio_client.make_bucket(bucket_destino)

# Refletir estrutura da tabela
metadata = MetaData()
metadata.reflect(bind=engine)
curation_table = Table("curation_audit", metadata, autoload_with=engine)

# Selecionar os 100 primeiros objetos válidos
objetos = list(minio_client.list_objects(bucket_origem, recursive=True))
objetos_validos = [obj for obj in objetos if obj.object_name and obj.object_name.strip()]
objetos_validos = objetos_validos[:100]

copiados = 0
erros = 0

for obj in tqdm(objetos_validos, desc="🔁 Copiando staging → curated"):
    try:
        object_name = obj.object_name
        raw_data = minio_client.get_object(bucket_origem, object_name).read()
        Image.open(io.BytesIO(raw_data))  # valida imagem

        # Upload para destino
        minio_client.put_object(
            bucket_name=bucket_destino,
            object_name=object_name,
            data=io.BytesIO(raw_data),
            length=len(raw_data),
            content_type="image/png"
        )

        # Audit coerente com constraint
        audit = {
            "prefix": object_name.split("/")[0],
            "full_path": f"{bucket_destino}/{object_name}",
            "filename": os.path.basename(object_name),
            "file_ext": os.path.splitext(object_name)[1].lower(),
            "curation_type": "manual_check",
            "curation_details": json.dumps({"bytes": len(raw_data)}),
            "timestamp": datetime.now(),
            "source_path": f"{bucket_origem}/{object_name}",
            "bucket_origin": bucket_origem,
            "bucket_curated": bucket_destino,
            "curation_status": "processed"  # ✅ valor aceito
        }

        with engine.begin() as conn:
            conn.execute(curation_table.insert().values(audit))
            copiados += 1

    except Exception as e:
        print(f"❌ Erro ao copiar {object_name}: {e}")
        erros += 1

# Relatório
print(f"\n✅ Verificação finalizada.")
print(f"✔️ {copiados} imagens copiadas e auditadas com sucesso.")
print(f"❌ {erros} imagens com erro.")
# Out:
# 🔁 Copiando staging → curated:   0%|          | 0/100 [00:00<?, ?it/s]
# ✅ Verificação finalizada.
# ✔️ 100 imagens copiadas e auditadas com sucesso.
# ❌ 0 imagens com erro.
